# %% [markdown]
# Download [austin_weather.csv](https://drive.google.com/uc?export=download&id=10JkPB2hhDmkVUoCGFP6gpoRL1mvx0OPf)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('austin_weather.csv')
df.head()
# Out:
#          Date  TempHighF  ...  PrecipitationSumInches               Events
# 0  2013-12-21         74  ...                    0.46  Rain , Thunderstorm
# 1  2013-12-22         56  ...                       0
# 2  2013-12-23         58  ...                       0
# 3  2013-12-24         61  ...                       0
# 4  2013-12-25         58  ...                       T
#
# [5 rows x 21 columns]

# %%
df.info()

# %% [markdown]
# <h2>Soal 1: Visualisasi Scatter Plot Perbandingan Kuantitatif</h2>
#
# Pada tugas kali ini kita akan mengamati nilai DewPointAvg (F) dengan mengamati nilai  HumidityAvg (%), TempAvg (F), dan WindAvg (MPG)
#
# Perhatikan bahwa data kita tidaklah siap untuk di analisis, salah satunya tipe data dari DewPointAvg (F), HumidityAvg (%), dan WindAvg (MPG) adalah object, padahalnya data nya ber isi numeric. maka :
# - Ubahlah tipe data tersebut menjadi tipe data float
#
# Kemudian:
#
# - Kalian tidak akan dengan mudah mengubah tipe data tersebut karena column tersebut mempunyai nilai '-' yang dimana tidak bisa di ubah ke bentuk float, maka replace lah terlebih dahulu data yang bernilai '-' dengan nilai NaN, gunakan method .replace(). baca dokumentasi https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.replace.html
# - Isi nilai nan dengan nilai sebelumnya di row tersebut. gunakan method .fillna() dengan argument method bernilai 'ffill', baca dokumentasi https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.fillna.html
# - Sekarang ubah tipe datanya dengan float, gunakan method .astype(), baca dokumentasi https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.astype.html
#
# Setelah ini sebagian data siap untuk di jadikan bahan analisis. maka:
#
# Buahlah visualisasi perbandingan kuantitatif scatter plot, sehingga menghasilkan gambar seperti dibawah:
#
# ket:
#
# - colormap adalah 'coolwarm'
# - berikat warna terhadap setiap data poin dengan nilai dari column TempAvgF
# - berikan size terhadap setiap data poin dengan nilai dari column WindAvgMPH, kalikan dengan 20 agar size terlihat lebih besar
#
#
# Berikan pendapat dari insight yang bisa di dapat dari visualisasi perbandingan kuantitatif ini!!!

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1Pp5oIc-39mcw2vrw6xgCRM9GsvyRtPI5)

# %%
# code here
df.replace('-', np.nan, inplace=True)
df[['DewPointAvgF', 'HumidityAvgPercent', 'WindAvgMPH']].fillna(method='ffill', inplace=True)
baru = df[['DewPointAvgF', 'HumidityAvgPercent', 'WindAvgMPH']].astype('float64')

fig, ax = plt.subplots(figsize=(12, 8))
plt.style.use('bmh')
x = baru['HumidityAvgPercent']
y = baru['DewPointAvgF']
warna = df['TempAvgF']
ukur = baru['WindAvgMPH']*20
axmap = ax.scatter(x, y, s=ukur, c=warna, cmap='coolwarm')
fig.colorbar(axmap)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4153: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# Downoad  <a href="https://blog.sanbercode.com/wp-content/uploads/2020/05/vgsales.csv">vgsales.csv</a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('vgsales.csv')
df.head()
# Out:
#    Rank                      Name Platform  ...  JP_Sales Other_Sales Global_Sales
# 0     1                Wii Sports      Wii  ...      3.77        8.46        82.74
# 1     2         Super Mario Bros.      NES  ...      6.81        0.77        40.24
# 2     3            Mario Kart Wii      Wii  ...      3.79        3.31        35.82
# 3     4         Wii Sports Resort      Wii  ...      3.28        2.96        33.00
# 4     5  Pokemon Red/Pokemon Blue       GB  ...     10.22        1.00        31.37
#
# [5 rows x 11 columns]

# %% [markdown]
# <h2>Soal 2: Preparing Data</h2>
#
# Manipulasi data tersebut dengan menggroupkan berdasarkan Genre, kemudian ambil rata2 penjualan untuk setiap Region Kecuali Global_Sales berdasarkan kategori Genre.

# %%
#code here
grapik = df.groupby('Genre')[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']].mean()
grapik
# Out:
#               NA_Sales  EU_Sales  JP_Sales  Other_Sales
# Genre
# Action        0.264726  0.158323  0.048236     0.056508
# Adventure     0.082271  0.049868  0.040490     0.013072
# Fighting      0.263667  0.119481  0.103007     0.043255
# Misc          0.235906  0.124198  0.061967     0.043312
# Platform      0.504571  0.227573  0.147596     0.058228
# Puzzle        0.212680  0.087251  0.098471     0.021564
# Racing        0.287766  0.190865  0.045388     0.061865
# Role-Playing  0.219946  0.126384  0.236767     0.040060
# Shooter       0.444733  0.239137  0.029221     0.078389
# Simulation    0.211430  0.130773  0.073472     0.036355
# Sports        0.291283  0.160635  0.057702     0.057532
# Strategy      0.100881  0.066579  0.072628     0.016681

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=1dR4vthSt22gM_LdfSBZCMIKPL6xd7nVl)

# %% [markdown]
# ---

# %% [markdown]
# <h2>Soal 3: Perbandingan Kuantitatif Barplot - Grouping Visualisasi Dengan Barplot</h2>
#
# 1. Visualisasikan gambar yang tadi kita manipulasi, untuk menghasilkan visualisasi seperti di bawah ini
# 2. Tuliskan apa insight yang bisa kamu dapat dari visualisasi tersebut

# %%
#code here
gt = grapik.transpose()
fig1, axx = plt.subplots(figsize = (12, 8))
plt.style.use('seaborn')
x = np.arange(0, 16,4)
y = gt['Action']
y2 = gt['Adventure']
y3 = gt['Fighting']
y4 = gt['Misc']
y5 = gt['Platform']
y6 = gt['Puzzle']
y7 = gt['Racing']
y8 = gt['Role-Playing']
y9 = gt['Shooter']
y10 = gt['Simulation']
y11 = gt['Sports']
y12 = gt['Strategy']
axx.bar(x, y, width=0.3, label='Action')
axx.bar(x+0.3,y2, width=0.3, label='Adventure')
axx.bar(x+0.6, y3, width=0.3, label='Fighting')
axx.bar(x+0.9, y4, width=0.3, label='Misc')
axx.bar(x+1.2, y5, width=0.3, label='Platform')
axx.bar(x+1.5, y6, width=0.3, label='Puzzle')
axx.bar(x+1.8, y7, width=0.3, label ='Racing')
axx.bar(x+2.1, y8, width=0.3, label='Role-Playing')
axx.bar(x+2.4, y9, width=0.3, label='Shooter')
axx.bar(x+2.7, y10, width=0.3, label='Simulation')
axx.bar(x+3, y11, width=0.3, label ='Sports')
axx.bar(x+3.3, y12, width=0.3, label='Strategy')
axx.set_ylabel('Mean Sales')
axx.set_xticklabels(list(gt.index))
axx.set_xticks(x+1.5)
axx.set_xlabel('Region Sales')
axx.set_title('Mean Sales Video Games by Genre')
plt.legend()
plt.show()

# %% [markdown]
# Jawab: Penjualan tertinggi terdapat pada North America dengan game bergenre platform dan shooter

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=1A2s9Uy2i471VEYIZqMoVUIlZnVOUc8ha)

# %% [markdown]
# ---

# %% [markdown]
# <h2>Soal 4: Perbandingan Kuantitatif Barplot - Stack Barplot</h2>
#
# 1. Visualisasikan gambar yang tadi kita manipulasi, untuk menhasilkan visualisasi seperti di bawah ini
# 2. Tuliskan apa insight yang bisa kamu dapat dari visualisasi tersebut

# %%
#code here
fig, axx = plt.subplots(figsize = (12, 8))
axx.bar(x, y, label='Action', width=3)
axx.bar(x,y2, bottom=y,  label='Adventure', width=3)
axx.bar(x, y3, bottom=y+y2, label='Fighting', width=3)
axx.bar(x, y4, bottom=y+y2+y3, label='Misc', width=3)
axx.bar(x, y5, bottom=y+y2+y3+y4, label='Platform', width=3)
axx.bar(x, y6, bottom=y+y2+y3+y4+y5, label='Puzzle', width=3)
axx.bar(x, y7, bottom=y+y2+y3+y4+y5+y6, label ='Racing', width=3)
axx.bar(x, y8, bottom=y+y2+y3+y4+y5+y6+y7, label='Role-Playing', width=3)
axx.bar(x, y9, bottom=y+y2+y3+y4+y5+y6+y7+y8, label='Shooter', width=3)
axx.bar(x, y10, bottom=y+y2+y3+y4+y5+y6+y7+y8+y9, label='Simulation', width=3)
axx.bar(x, y11, bottom=y+y2+y3+y4+y5+y6+y7+y8+y9+y10, label ='Sports', width=3)
axx.bar(x, y12, bottom=y+y2+y3+y4+y5+y6+y7+y8+y9+y10+y11, label='Strategy', width=3)
axx.set_ylabel('Mean Sales')
axx.set_xticklabels(list(gt.index))
axx.set_xticks(x+0.1)
axx.set_xlabel('Region Sales')
axx.set_title('Mean Sales Video Games by Genre')
plt.legend()
plt.show()

# %% [markdown]
# Jawab: Penjualan game tertinggi terdapat pada north america

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=1_yis-3aZsEbsk68tpoPHoNlFftaz2GrO)
