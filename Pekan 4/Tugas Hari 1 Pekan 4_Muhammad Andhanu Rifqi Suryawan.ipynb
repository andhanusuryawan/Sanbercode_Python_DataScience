# %% [markdown]
# <h1>Soal 1: Pemahaman Machine Learning</h1>
#
# Jawab/Kerjakan pertanyaan/perintah di bawah ini dengan bahasa kalian sendiri:
#
# - Apa itu machine learning?
# - Apa itu data feature dan data target?
# - Apa Perbedaan Supervised Learning dan Unsupervised Learning?
# - Apa Jenis2 yang ada di dalam Supervised Learning? Jelaskan Perbedaannya!
# - Apa perbedaan Hyperparameter dan Parameter?
# - Sebutkan Langkah-langkah dalam mengaplikasikan algoritma apapun dalam machine learning!

# %% [markdown]
# 1. Machine learning merupakan sebuah cabang dari ilmu kecerdasan buatan yang mempelajari bagaimana komputer mampu membuat suatu prediksi terhadap data baru berdasarkan kumpulan data yang kita berikan.
# 2. Data feature merupakan data yang akan membuat prediksi terhadap suatu data baru, sedangkan Data Target adalah variabel yang digunakan untuk klasifikasi terhadap hasil dari prediksi data baru.
# 3. Pada Supervised Learning, kita menggunakan data latih untuk membantu mesin mengenali unlabeled data, sedangkan pada Unsupervised Learning tidak menggunakan data latih, sehingga mesin akan mempelajari unlabeled data berdasarkan fitur-fitur dari data tersebut.
# 4. Klasifikasi dan Regresi, perbedaannya adalah pada outputnya. Pada klasifikasi, output berupa class label, sedangkan pada regresi berupa nilai yang bersifat kontinyu.
# 5. Hyperparameter **didefinisikan** di awal pembuatan model, sedangkan parameter  **dihasilkan** di akhir
# 6. 1. Pilih model algorithm yang akan digunakan
#    2. Pilih hyperparameter ketika membuat objek model
#    3. Pisahkan antara data feature dan data target
#    4. Perintahkan model untuk mempelajari data dengan method .fit()
#    5. Aplikasikan model ke dalam test data dengan menggunakan method .predict() untuk supervised learning atau .transform() dan .predict() untuk unsupervised learning.

# %% [markdown]
# <h1>Soal 2: Pemahaman Machine Learning</h1>
#
# Pelajarilah secara garis besar suatu model/algoritma machine learning, kemudian aplikasikan untuk membuat model bagi data (variable x, y) di bawah ini. Kemudian buatlah prediksi terhadap data training dan data baru di interval 20-30.
#
# - Plot data asli, data hasil prediksi terhadap data training, data hasil prediksi terhadap data baru
# - Tunjukan beberapa parameter yang dimiliki model yang telah kalian buat

# %%
import matplotlib.pyplot as plt
import numpy as np

rng = np.random.RandomState(42)
x = 20 * rng.rand(50)
y = x**2 + 2 * x + - 1 + rng.randn(50)

# data yang akan di prediksi
x_new = np.arange(20, 30, 0.5)

fig, ax = plt.subplots(figsize=(12, 6))
ax.scatter(x, y)
ax.set_xlabel('X-Value')
ax.set_ylabel('Y-Value')
plt.show()

# %% [markdown]
# Contoh jawaban hasil pembuatan model dengan algoritma DecisionTreeRegressor (jawaban tidak harus sama):
#
# ![alt text](https://drive.google.com/uc?id=1R0mGnMp3DqEsHDiH2_IL4XSS2Roew0wo)

# %% [markdown]
# Contoh jawaban parameters (tidak harus sama):
#
# - Feature Importance : array([1.])
# - n features : 1
#
# Tree Graph :
#
# ![alt text](https://drive.google.com/uc?id=1GM0ba_qjm_e5oLhE9v6pVt2uRBBW6FH9)

# %%
# Code here
from sklearn.tree import DecisionTreeRegressor
model_lr=DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=4,
                      max_features=None, max_leaf_nodes=7,
                      min_impurity_decrease=0.0, min_impurity_split=None,
                      min_samples_leaf=5, min_samples_split=2,
                      min_weight_fraction_leaf=0.0, presort='deprecated',
                      random_state=None, splitter='best')
x_matrix=x[:, np.newaxis]
x_baru=x_new[:, np.newaxis]
model_lr.fit(x_matrix, y)
y_test=model_lr.predict(x_baru)
y_train=model_lr.predict(x_matrix)

# %%
x_baru.shape
# Out:
# (20, 1)

# %%
fig1, axx = plt.subplots(figsize=(12, 6))
axx.scatter(x, y, color='b', label='Data Asli')
axx.scatter(x_matrix, y_train,color='y', label='Prediksi Terhadap Data Training')
axx.plot(x_baru, y_test,color='g', label='Prediksi Terhadap Data baru')
axx.set_xlabel('X-Value')
axx.set_ylabel('Y-Value')
plt.legend(bbox_to_anchor=(1.1,1.2))
plt.show()
tree.plot_tree(model_rgr);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e8dfb3ee7316> in <module>()
#       7 plt.legend(bbox_to_anchor=(1.1,1.2))
#       8 plt.show()
# ----> 9 tree.plot_tree(model_rgr);
#
# NameError: name 'tree' is not defined

# %%
x_test.shape
# Out:
# (20, 1)
